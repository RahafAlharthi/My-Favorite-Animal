# %% [markdown]
# <a href="https://colab.research.google.com/github/RahafAlharthi/My-Favorite-Animal/blob/master/Smart_Cities_exercise_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
# # Upload Dataset : https://www.kaggle.com/datasets/magdamonteiro/smart-cities-index-datasets
#
# ## The dataset contains information about Used Cars Price with the following columns:
#
# `Id`: Column identifier
#
# `City`: List of countries where smart cities across the world are located.
#
# `Country`: The location in which the car is being sold or is available for purchase.
#
# `Smart_Mobility`: Index calculated from assessment of city-wide Public Transportation System, ICT, accessibility infrastructure..
#
# `Smart_Environment`: Index calculated from environmental sustainability impact, monitoring pollution and energy management.
#
# `Smart_Government`: Index calculated from comparative study of transparent governance & open data initiatives of smart cities across the
#
# `Smart_Economy`: Index calculated through global comparison of city-wide productivity, economic vitality, and support for
#
# `Smart_People`: Index calculated by comparing social and cultural plurality, education systems and its supporting ancillary.
#
# `Smart_Living`: Index calculated by measuring metric around healthcare services, social security and housing quality.
#
# `SmartCity_Index`: Aggregate score for smart city model based on smart city supergroups.

# %% [markdown]
# #Tasks

# %% [markdown]
# ## 1 . Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
df=pd.read_csv("/content/Datasets/Smart_City_index_headers.csv")
df.head()
# Out:
#    Id        City      Country  Smart_Mobility   Smart_Environment  \
# 0   1        Oslo       Norway             6480               6512
# 1   2      Bergen       Norway             7097               6876
# 2   3   Amsterdam  Netherlands             7540               5558
# 3   4  Copenhagen      Denmark             7490               7920
# 4   5   Stockholm       Sweden             6122               7692
#
#    Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 0               7516            4565          8618          9090
# 1               7350            4905          8050          9090
# 2               8528            8095          7098          7280
# 3               8726            5580          5780          7200
# 4               8354            4330          6743          7730
#
#    SmartCity_Index  SmartCity_Index_relative_Edmonton
# 0             7138                                666
# 1             7296                                823
# ...

# %%
df.shape
# Out:
# (102, 11)

# %% [markdown]
# ### Handling Missing Values

# %%
df.isnull().sum()
# Out:
# Id                                   0
# City                                 0
# Country                              0
# Smart_Mobility                       0
# Smart_Environment                    0
# Smart_Government                     0
# Smart_Economy                        0
# Smart_People                         0
# Smart_Living                         0
# SmartCity_Index                      0
# SmartCity_Index_relative_Edmonton    0
# dtype: int64

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['City'].value_counts()
# Out:
# City
# Oslo            1
# Brussels        1
# Dubai           1
# Tallinn         1
# Nice            1
#                ..
# Hamburg         1
# Philadelphia    1
# Munich          1
# Helsingborg     1
# Edmonton        1
# Name: count, Length: 102, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# Italy                   11
# Finland                 10
# Germany                 10
# United States            7
# France                   7
# Canada                   6
# Norway                   4
# Australia                4
# Denmark                  4
# Sweden                   3
# United Kingdom           3
# China                    3
# South Korea              2
# Spain                    2
# Japan                    2
# United Arab Emirates     2
# Switzerland              2
# Russia                   2
# Hungary                  1
# Czech Republic           1
# Israel                   1
# Malaysia                 1
# Slovenia                 1
# Slovakia                 1
# Portugal                 1
# New Zealand              1
# Estonia                  1
# Ireland                  1
# Belgium                  1
# Netherlands              1
# Luxembourg               1
# Iceland                  1
# Taiwan                   1
# Singapore                1
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Id                                    int64
# City                                 object
# Country                              object
# Smart_Mobility                        int64
# Smart_Environment                     int64
# Smart_Government                      int64
# Smart_Economy                         int64
# Smart_People                          int64
# Smart_Living                          int64
# SmartCity_Index                       int64
# SmartCity_Index_relative_Edmonton     int64
# dtype: object

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %%
df.head()
# Out:
#    Id        City      Country  Smart_Mobility   Smart_Environment  \
# 0   1        Oslo       Norway             6480               6512
# 1   2      Bergen       Norway             7097               6876
# 2   3   Amsterdam  Netherlands             7540               5558
# 3   4  Copenhagen      Denmark             7490               7920
# 4   5   Stockholm       Sweden             6122               7692
#
#    Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 0               7516            4565          8618          9090
# 1               7350            4905          8050          9090
# 2               8528            8095          7098          7280
# 3               8726            5580          5780          7200
# 4               8354            4330          6743          7730
#
#    SmartCity_Index  SmartCity_Index_relative_Edmonton
# 0             7138                                666
# 1             7296                                823
# ...

# %%
df.tail()
# Out:
#       Id           City Country  Smart_Mobility   Smart_Environment  \
# 97    98           Riga  Latvia             4152               4584
# 98    99        Beijing   China             7610               2998
# 99   100  St Petersburg  Russia             4588               2908
# 100  101        Calgary  Canada             6675               4052
# 101  102       Edmonton  Canada             5801               4499
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 97                4616            7380          3745          4330
# 98                2806            4905          5183          1980
# 99                3622            4515          5390          4100
# 100               5946            8022          6424          8657
# 101               6396            8022          6200          8141
#
#      SmartCity_Index  SmartCity_Index_relative_Edmonton
# 97              4712                              -1760
# ...

# %%
df.sample(10)
# Out:
#       Id        City         Country  Smart_Mobility   Smart_Environment  \
# 53    54       Tokyo           Japan             7787               4516
# 7      8      Odense         Denmark             6160               8404
# 65    66   Marseille          France             6087               7010
# 20    21      Berlin         Germany             7677               7090
# 79    80  Birmingham  United Kingdom             6383               7102
# 64    65    Brussels         Belgium             4447               5950
# 19    20   Vancouver          Canada             5975               5348
# 31    32     Hamburg         Germany             7273               7272
# 33    34  Luxembourg      Luxembourg             3747               7090
# 100  101     Calgary          Canada             6675               4052
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 53                5476            1800          4158          9320
# ...

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#                Id  Smart_Mobility   Smart_Environment  Smart_Government   \
# count  102.000000       102.000000         102.000000         102.000000
# mean    51.500000      5759.401961        5943.500000        5893.803922
# std     29.588849      1214.030137        1724.032171        1153.375297
# min      1.000000      3175.000000        1850.000000        2806.000000
# 25%     26.250000      4809.750000        4530.500000        5143.000000
# 50%     51.500000      5651.500000        6495.000000        5911.000000
# 75%     76.750000      6763.750000        7310.000000        6581.500000
# max    102.000000      8110.000000        8844.000000        8726.000000
#
#        Smart_Economy   Smart_People  Smart_Living  SmartCity_Index  \
# count      102.000000    102.000000    102.000000       102.000000
# mean      6131.803922   5874.049020   6377.039216      5991.911765
# std       1801.555148   1449.096341   2286.397477       852.775180
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
top_cars = df['Country'].value_counts().head(5)
plt.figure(figsize=(10, 6))
top_cars.plot(kind='bar', color='skyblue')
plt.title('Top 5 Country of smart cities')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
top_cars = df['Country'].value_counts().tail(5)
plt.figure(figsize=(10, 6))
top_cars.plot(kind='bar', color='skyblue')
plt.title('Least 5 Country of smart cities')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Visualize the distribution of key variables.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['Smart_Mobility '], kde=True, color='skyblue')
plt.title('Histogram of Smart Mobility')
# Out:
# Text(0.5, 1.0, 'Histogram of Smart Mobility')

# %%
sns.histplot(df['Smart_Environment'], kde=True, color='skyblue')
plt.title('Histogram of Smart Smart Environment')
# Out:
# Text(0.5, 1.0, 'Histogram of Smart Smart Environment')

# %%
sns.histplot(df['Smart_Government '], kde=True, color='skyblue')
plt.title('Histogram of Smart Government')
# Out:
# Text(0.5, 1.0, 'Histogram of Smart Government')

# %% [markdown]
# ### Explore relationships between variables.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Plot correlation matrix as scatter
plt.figure(figsize=(10, 8))
plt.scatter(df['Smart_Environment'], df['Smart_Government '], color='blue', alpha=0.5)

# %%
plt.figure(figsize=(10, 8))
plt.scatter(df['Smart_Environment'], df['Smart_People'], color='blue', alpha=0.5)

# %%
correlation = df['Smart_Economy '].corr(df['Smart_Government '])
print("Correlation between Smart Economy and Smart Government:", correlation)
# Out:
# Correlation between Smart Economy and Smart Government: 0.16021479426148702

# %%
plt.scatter(df['Smart_Economy '],df['Smart_Government '], color='blue', alpha=0.5)

# %%
f = (
    df.loc[:,['Smart_Mobility ', 'Smart_Environment',
       'Smart_Government ', 'Smart_Economy ', 'Smart_People', 'Smart_Living',
       'SmartCity_Index', 'SmartCity_Index_relative_Edmonton']]
   .dropna()
).corr()

# %%
sns.heatmap(f, annot=True)
# Out:
# <Axes: >
